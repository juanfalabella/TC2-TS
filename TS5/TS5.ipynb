# %% [markdown]
# <div align="center">
#     <h2>Tarea Semanal 5</h2>
#     <h1>Juan Ignacio Falabella</h1>
# </div>
#
# ![logoUTN](logoUTN.png "UTN FRBA")
#
#
# <div align="center">
#     <h2>Entrega parcial 13/6. Entrega completa 10/07</h2>
# </div>
#
#
# ![ts5Foto1](ts5Foto1.png "ts5Foto1")
# ![ts5Foto2](ts5Foto2.png "ts5Foto2")
# ![ts5Foto3](ts5Foto3.png "ts5Foto3")
# ![ts5Foto4](ts5Foto4.png "ts5Foto4")
# ![ts5Foto5](ts5Foto5.png "ts5Foto5")
#
# ![ts5-2-a](ts5-2-a.png "ts5-2-a")

# %%
import scipy.signal as sig
from mpl_toolkits.mplot3d import Axes3D
import pylab
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from splane import pzmap, grpDelay, bodePlot, convert2SOS
import math

plt.close('all')

Q=5
num = [1/4,0,1]
den = [1,1.4142,1]

myFilter = sig.TransferFunction(num,den)

bodePlot(myFilter)

pzmap(myFilter)


plt.rcParams.update({'font.size': 16})

plt.show()
# Out:
# 2 zeros: [-0.+2.j  0.-2.j]
# 2 poles: [-0.7071+0.70711356j -0.7071-0.70711356j]
# gain: 0.25

# %% [markdown]
# ![ts5-2-b](ts5-2-b.png "ts5-2-b")

# %%
import scipy.signal as sig
from mpl_toolkits.mplot3d import Axes3D
import pylab
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from splane import pzmap, grpDelay, bodePlot, convert2SOS
import math

plt.close('all')

Q=5
num = [1,0,1]
den = [1,1.4142,1]

myFilter = sig.TransferFunction(num,den)

bodePlot(myFilter)

pzmap(myFilter)


plt.rcParams.update({'font.size': 16})

plt.show()
# Out:
# 2 zeros: [-0.+1.j  0.-1.j]
# 2 poles: [-0.7071+0.70711356j -0.7071-0.70711356j]
# gain: 1.0

# %% [markdown]
# ![ts5-2-c](ts5-2-c.png "ts5-2-c")

# %%
import scipy.signal as sig
from mpl_toolkits.mplot3d import Axes3D
import pylab
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from splane import pzmap, grpDelay, bodePlot, convert2SOS
import math

plt.close('all')

Q=5
num = [1,-1.4142,1]
den = [1,1.4142,1]

myFilter = sig.TransferFunction(num,den)

w, mag, phase = myFilter.bode(n=200)

 #  plt.figure()
plt.figure("Magnitude response")
plt.semilogx(w, mag)    # Bode magnitude plot
plt.ylim(-2,2)
plt.grid(True)
plt.xlabel('Angular frequency [rad/sec]')
plt.ylabel('Magnitude response [dB]')
plt.title('Frequency response')
   
#   plt.figure()
plt.figure("Phase response")
plt.semilogx(w, phase)    # Bode phase plot
plt.grid(True)
plt.xlabel('Angular frequency [rad/sec]')
plt.ylabel('Phase response [deg]')
plt.title('Frequency response')
    
pzmap(myFilter)


plt.rcParams.update({'font.size': 16})

plt.show()
# Out:
# 2 zeros: [0.7071+0.70711356j 0.7071-0.70711356j]
# 2 poles: [-0.7071+0.70711356j -0.7071-0.70711356j]
# gain: 1.0

# %% [markdown]
# ![ts5-2-d](ts5-2-d.png "ts5-2-d")

# %%
import scipy.signal as sig
from mpl_toolkits.mplot3d import Axes3D
import pylab
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from splane import pzmap, grpDelay, bodePlot, convert2SOS
import math

plt.close('all')

Q=5
num = [1,0,16]
den = [1,1.4142,1]

myFilter = sig.TransferFunction(num,den)

bodePlot(myFilter)

pzmap(myFilter)


plt.rcParams.update({'font.size': 16})

plt.show()
# Out:
# 2 zeros: [-0.+4.j  0.-4.j]
# 2 poles: [-0.7071+0.70711356j -0.7071-0.70711356j]
# gain: 1.0

# %% [markdown]
# ![ts5Foto6](ts5Foto6.png "ts5Foto6")
